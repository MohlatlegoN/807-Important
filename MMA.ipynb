# %%
import pandas as pd

# %%
df1 =pd.read_json("data/external/complaints_from_2020_01_01_to_2021_12_31__2022_03_22_facebook (1).json")
df1
# Out:
#         id                                         source_url  \
# 214    259  https://m.facebook.com/comment/replies/?ctoken...
# 223    268   https://www.facebook.com/groups/1552048541617075
# 227    272  https://m.facebook.com/story.php?story_fbid=91...
# 236    281  https://m.facebook.com/story.php?story_fbid=20...
# 238    283  https://www.facebook.com/groups/jeffreysbayonl...
# ...    ...                                                ...
# 1913  2013  https://m.facebook.com/story.php?story_fbid=11...
# 1933  2033  https://www.facebook.com/1032853733/posts/1022...
# 1947  2047  https://m.facebook.com/story.php?story_fbid=10...
# 1948  2048  https://m.facebook.com/story.php?story_fbid=10...
# 1972  2072            https://www.facebook.com/sluierderidder
#
#                                                   title  \
# 214   Facemasks are not necessary in those who are a...
# 223                               #endthelockdownmzansi
# ...

# %%
df2 =pd.read_json("data/external/complaints_from_2020_01_01_to_2021_12_31__2022_03_22_twitter (1).json")

# %%
df2.asset_text_extracts
# Out:
# 228     t2 Thailys Retweeted\nMarxist\n@Kgomo389\n#Mad...
# 237     Tweet\nBoerelegioen\n@Boerelegioen2\nPolice co...
# 263     Dear cleverblacks, mlungu is\nnot your friend\...
# 287     Helen Zille\n@helenzille\nOnce you have health...
# 289     02:43\nda.org.za\nDA\nMENU\nThe crue praveny a...
#                               ...
# 1954    Thread\nACDP South Africa\nv\nACDP\n@A_C_D_P\n...
# 1956    23:14\nit\nLie all 29%\nmobile.twitter.com/a_c...
# 1957    4G\na\n04\n94) 23:26\nmobile.twitter.com/A_C.\...
# 1958    ACDP South Africa\n@A_C_D_P Dec 10\nACDP\nCovi...
# 1959    W\nN\nHOME LOCAL ELECTIONS CORONAVIRUS SPORT L...
# Name: asset_text_extracts, Length: 576, dtype: object
