# %%
import urllib 
import json
import pandas as pd

# %%
path = "data/complaints_from_2020_01_01_to_2021_12_31__2022_03_22_twitter.json"
f = open(path)

# %%
f
# Out:
# <_io.TextIOWrapper name='data/complaints_from_2020_01_01_to_2021_12_31__2022_03_22_twitter.json' mode='r' encoding='cp1252'>

# %%
data = json.load(f)

# %%
data
# Out:
# {'id': {'228': 273,
#   '237': 282,
#   '263': 308,
#   '287': 341,
#   '289': 343,
#   '305': 359,
#   '317': 371,
#   '324': 378,
#   '332': 386,
#   '344': 398,
#   '353': 407,
#   '380': 434,
#   '382': 436,
#   '383': 437,
#   '412': 466,
#   '414': 468,
#   '418': 472,
#   '422': 476,
#   '424': 478,
#   '425': 479,
#   '426': 480,
#   '427': 481,
#   '428': 482,
#   '430': 484,
#   '431': 485,
#   '432': 486,
#   '433': 487,
#   '436': 490,
#   '437': 491,
#   '440': 494,
#   '441': 495,
#   '442': 496,
#   '443': 497,
#   '444': 498,
#   '448': 502,
#   '458': 512,
#   '461': 515,
#   '463': 517,
#   '464': 518,
#   '466': 520,
#   '467': 521,
#   '468': 522,
#   '469': 523,
#   '470': 524,
#   '475': 529,
#   '482': 536,
#   '483': 537,
#   '484': 538,
#   '485': 539,
#   '487': 541,
#   '488': 542,
#   '494': 548,
#   '495': 549,
#   '500': 554,
#   '501': 555,
#   '502': 556,
#   '503': 557,
#   '505': 559,
#   '506': 560,
#   '507': 561,
#   '508': 562,
#   '509': 563,
# ...

# %%
df = pd.json_normalize(data['title'])

# %%
df.T
# Out:
#                                                       0
# 228               Madagascar medicine 80% recovery rate
# 237   Claim of white people being starved in South A...
# 263   Everything @Fred41848816: Tweets Containing Pu...
# 287                 Helen Zille Tweet regarding COVID19
# 289                  DA Voices Opinion against Lockdown
# ...                                                 ...
# 1954
# 1956
# 1957
# 1958
# 1959  Twitter: " 13 patients injected with saline so...
#
# [576 rows x 1 columns]
